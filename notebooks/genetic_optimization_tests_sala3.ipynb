# %% [markdown]
# ## Se prueba la etapa completa de optimización

# %%
import os
import time
os.chdir('..')

# %%
from outline_optim import find_best_outline
from complex_outline_optim import find_complex_outline_gen2, find_complex_outline_gen3, find_complex_outline_gen4, calculate_initial
# Out:
# /home/diber/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# Defino las condiciones (el input del usuario)

# %%
# Condiciones de la sala
Lx = 4        # Largo de la sala en X 
Ly = 6        # Largo de la sala en Y
Lz = 3        # Alto de la sala
Dx = 0.8      # Delta X
Dy = 1.5      # Delta Y
Dz = 0.5      # Delta Z

## Posiciones fuente y receptor (en metros)
source_position = (3, 4, 1.3)
receptor_position = (2, 2, 1.2)

## Número de cortes en las paredes
n_walls = 2    

## Tipo de optimización (slow, medium, fast)
optim_type = "slow"

# %% [markdown]
# Proceso de optimización tipo algorítmo genético

# %%
if optim_type == "fast":
    salas_g1 = 500
    salas_g2 = 150     # Cantidad de salas para iterar
    salas_g3 = 10      # Cantidad de salas random para agregar
    next_gen_g3 = 10   # Cantidad de salas que pasan de la iteración anterior
    next_gen_g4 = 3    # Cantidad de salas que pasan de la iteración anterior
    mut_ammount = 2    # Cantidad de mutaciones por sala

if optim_type == "medium":
    salas_g1 = 1000
    salas_g2 = 300     # Cantidad de salas para iterar
    salas_g3 = 20      # Cantidad de salas random para agregar
    next_gen_g3 = 20   # Cantidad de salas que pasan de la iteración anterior
    next_gen_g4 = 3    # Cantidad de salas que pasan de la iteración anterior
    mut_ammount = 4    # Cantidad de mutaciones por sala

if optim_type == "slow":
    salas_g1 = 5000
    salas_g2 = 600     # Cantidad de salas para iterar
    salas_g3 = 100      # Cantidad de salas random para agregar
    next_gen_g3 = 50   # Cantidad de salas que pasan de la iteración anterior
    next_gen_g4 = 5    # Cantidad de salas que pasan de la iteración anterior
    mut_ammount = 6    # Cantidad de mutaciones por sala

## 0) Evalúa condiciones iniciales
start0 = time.time()
merit_0, mag0 = calculate_initial(Lx, Ly, Lz, source_position, receptor_position)
time0 = time.time() - start0

## 1) Mejores dimensiones con geometrías simples
start1 = time.time()
final_best_room, best_room_spacing, merit_gen1_modal, mag_gen1_modal = find_best_outline(Lx, Ly, Lz, Dx, Dy, Dz, source_position, receptor_position, salas_g1)

# Define nuevas posiciones para estas dimensiones(sería como una translación del problema al subcuadrado mas chico)
Lx_new, Ly_new, Lz_new = final_best_room
Dx_new, Dy_new = best_room_spacing
dx_room = (Lx - Lx_new)/2
dy_room = (Ly - Ly_new)/2
new_source_pos = (source_position[0] - dx_room, source_position[1] - dy_room, source_position[2])
new_receptor_pos = (receptor_position[0] - dx_room, receptor_position[1] - dy_room, receptor_position[2])

merit_g1, mag_g1 = calculate_initial(Lx_new, Ly_new, Lz, source_position, receptor_position)
time1 = time.time() - start1

## 2) Geometría compleja partiendo de mejor geometría simple
start2 = time.time()
best_rooms_g2, merits_g2, mags_g2 = find_complex_outline_gen2(Lx_new, Ly_new, Lz_new, Dx_new, Dy_new, new_source_pos, new_receptor_pos, n_walls, salas_g2) 
time2 = time.time() - start2

## 3) Geometría compleja mas ancho de banda
start3 = time.time()
best_rooms_g3, merits_g3, mag_g3 = find_complex_outline_gen3(Lx_new, Ly_new, Lz_new, Dx_new, Dy_new, new_source_pos, new_receptor_pos, n_walls, best_rooms_g2[:next_gen_g3], salas_g3) 
time3 = time.time() - start3

## 4) Geometría compleja mas ancho de banda y resolución (se introducen mutaciones)
start4 = time.time()
best_rooms_g4, merits_g4, mag_g4 = find_complex_outline_gen4(Lx_new, Ly_new, Lz_new, Dx_new, Dy_new, new_source_pos, new_receptor_pos, best_rooms_g3[:next_gen_g4], mut_ammount) 
time4 = time.time() - start4
# Out:
# Info    : Reading 'mallado/room_base_optim.msh'...
# Info    : 33 entities
# Info    : 6201 nodes
# Info    : 36807 elements
# Info    : Done reading 'mallado/room_base_optim.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 571 nodes
# Info    : 3095 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1590 nodes
# Info    : 8897 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 579 nodes
# Info    : 3145 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1648 nodes
# Info    : 9230 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 598 nodes
# Info    : 3241 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1474 nodes
# Info    : 8200 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 608 nodes
# Info    : 3347 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1439 nodes
# Info    : 8012 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 540 nodes
# Info    : 2934 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1511 nodes
# Info    : 8418 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 530 nodes
# Info    : 2894 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1301 nodes
# Info    : 7230 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 596 nodes
# Info    : 3247 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1505 nodes
# Info    : 8366 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 591 nodes
# Info    : 3217 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1407 nodes
# Info    : 7854 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 605 nodes
# Info    : 3280 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1442 nodes
# Info    : 8035 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 588 nodes
# Info    : 3209 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1402 nodes
# Info    : 7769 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 516 nodes
# Info    : 2783 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1362 nodes
# Info    : 7607 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 720 nodes
# Info    : 3979 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1429 nodes
# Info    : 7996 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 568 nodes
# Info    : 3106 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1405 nodes
# Info    : 7829 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 582 nodes
# Info    : 3133 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1437 nodes
# Info    : 8018 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 597 nodes
# Info    : 3246 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1565 nodes
# Info    : 8796 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 636 nodes
# Info    : 3450 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1606 nodes
# Info    : 8976 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 602 nodes
# Info    : 3266 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1478 nodes
# Info    : 8239 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 664 nodes
# Info    : 3613 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1611 nodes
# Info    : 9008 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 542 nodes
# Info    : 2956 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1472 nodes
# Info    : 8239 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 551 nodes
# Info    : 3001 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1301 nodes
# Info    : 7239 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 521 nodes
# Info    : 2801 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1354 nodes
# Info    : 7488 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 657 nodes
# Info    : 3600 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1516 nodes
# Info    : 8445 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 549 nodes
# Info    : 2990 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1370 nodes
# Info    : 7594 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 612 nodes
# Info    : 3305 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1466 nodes
# Info    : 8136 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 518 nodes
# Info    : 2828 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1423 nodes
# Info    : 7920 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 607 nodes
# Info    : 3312 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1493 nodes
# Info    : 8355 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 563 nodes
# Info    : 3057 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1417 nodes
# Info    : 7878 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 593 nodes
# Info    : 3246 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1403 nodes
# Info    : 7789 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 591 nodes
# Info    : 3208 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1387 nodes
# Info    : 7702 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    :
elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 542 nodes
# Info    : 2967 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1289 nodes
# Info    : 7109 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3354 nodes
# Info    : 19521 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 549 nodes
# Info    : 3012 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1220 nodes
# Info    : 6707 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3516 nodes
# Info    : 20533 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 520 nodes
# Info    : 2805 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1248 nodes
# Info    : 6889 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3662 nodes
# Info    : 21411 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 598 nodes
# Info    : 3241 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1340 nodes
# Info    : 7440 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3797 nodes
# Info    : 22142 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 567 nodes
# Info    : 3072 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1251 nodes
# Info    : 6875 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3656 nodes
# Info    : 21284 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 616 nodes
# Info    : 3388 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1300 nodes
# Info    : 7194 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3799 nodes
# Info    : 22208 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 602 nodes
# Info    : 3276 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1266 nodes
# Info    : 6961 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3604 nodes
# Info    : 21028 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 600 nodes
# Info    : 3287 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1306 nodes
# Info    : 7245 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3882 nodes
# Info    : 22734 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 547 nodes
# Info    : 2945 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1291 nodes
# Info    : 7131 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3872 nodes
# Info    : 22702 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 591 nodes
# Info    : 3227 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1278 nodes
# Info    : 7032 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4129 nodes
# Info    : 23742 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 595 nodes
# Info    : 3249 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1346 nodes
# Info    : 7467 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3946 nodes
# Info    : 23083 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 603 nodes
# Info    : 3281 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1370 nodes
# Info    : 7591 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3774 nodes
# Info    : 22020 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 623 nodes
# Info    : 3427 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1366 nodes
# Info    : 7564 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3879 nodes
# Info    : 22594 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 574 nodes
# Info    : 3108 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1344 nodes
# Info    : 7367 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3633 nodes
# Info    : 21221 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 582 nodes
# Info    : 3179 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1346 nodes
# Info    : 7448 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4190 nodes
# Info    : 24093 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'

# %% [markdown]
# Resultados con configuración FAST:

# %%
print("El valor original de mérito es: ", merit_0)
print("Tiempo de ejecución en minutos fue de: ", time0/60)
print("...................")
print("Gen 1(con modal sum y geometrías simples)")
print("El mejor mérito es: ", merit_gen1)
print("Tiempo de ejecución en minutos fue de: ", time1/60)
print("...................")
print("Gen 2 (con FEM Source hasta 150 Hz | res=2)")
print("El mejor mérito es ", merits_g2[0])
print("Tiempo de ejecución en minutos fue de: ", time2/60)
print("...................")
print("Gen 3 (con FEM Source hasta 180 Hz | res=2)")
print("El mejor mérito es ", merits_g3[0])
print("Tiempo de ejecución en minutos fue de: ", time3/60)
print("...................")
print("Gen 4 (con FEM Source hasta 200 Hz | res=1)")
print("El mejor mérito es ", merits_g4[0])
print("Tiempo de ejecución en minutos fue de: ", time4/60)
# Out:
# El valor original de mérito es:  (16.524101304062047, 13.19659279917218, 3.327508504889866)
# Tiempo de ejecución en minutos fue de:  0.874497385819753
# ...................
# Gen 1(con modal sum y geometrías simples)
# El mejor mérito es:  (14.285066525917438, 10.97100062600868, 3.3140658999087584)
# Tiempo de ejecución en minutos fue de:  0.013919444878896077
# ...................
# Gen 2 (con FEM Source hasta 150 Hz | res=2)
# El mejor mérito es  14.184145622984715
# Tiempo de ejecución en minutos fue de:  4.408021708329518
# ...................
# Gen 3 (con FEM Source hasta 180 Hz | res=2)
# El mejor mérito es  15.994558063331276
# Tiempo de ejecución en minutos fue de:  0.46861835320790607
# ...................
# Gen 4 (con FEM Source hasta 200 Hz | res=1)
# El mejor mérito es  16.802935521522773
# Tiempo de ejecución en minutos fue de:  1.1645455876986186

# %% [markdown]
# Resultado con configuración MEDIUM:

# %%
print("El valor original de mérito es: ", merit_0)
print("Tiempo de ejecución en minutos fue de: ", time0/60)
print("...................")
print("Gen 1(con modal sum y geometrías simples)")
print("El mejor mérito es: ", merit_gen1)
print("Tiempo de ejecución en minutos fue de: ", time1/60)
print("...................")
print("Gen 2 (con FEM Source hasta 150 Hz | res=2)")
print("El mejor mérito es ", merits_g2[0])
print("Tiempo de ejecución en minutos fue de: ", time2/60)
print("...................")
print("Gen 3 (con FEM Source hasta 180 Hz | res=2)")
print("El mejor mérito es ", merits_g3[0])
print("Tiempo de ejecución en minutos fue de: ", time3/60)
print("...................")
print("Gen 4 (con FEM Source hasta 200 Hz | res=1)")
print("El mejor mérito es ", merits_g4[0])
print("Tiempo de ejecución en minutos fue de: ", time4/60)
print("...................")
print("Tiempo total en minutos: ", (time0 + time1 + time2 + time3 + time4)/60)
# Out:
# El valor original de mérito es:  (16.524101304062047, 13.19659279917218, 3.327508504889866)
# Tiempo de ejecución en minutos fue de:  0.8952393333117167
# ...................
# Gen 1(con modal sum y geometrías simples)
# El mejor mérito es:  (13.919221846349062, 10.950294932619432, 2.9689269137296304)
# Tiempo de ejecución en minutos fue de:  0.026402699947357177
# ...................
# Gen 2 (con FEM Source hasta 150 Hz | res=2)
# El mejor mérito es  12.918051619006025
# Tiempo de ejecución en minutos fue de:  9.891285705566407
# ...................
# Gen 3 (con FEM Source hasta 180 Hz | res=2)
# El mejor mérito es  15.1728637367741
# Tiempo de ejecución en minutos fue de:  1.0311959266662598
# ...................
# Gen 4 (con FEM Source hasta 200 Hz | res=1)
# El mejor mérito es  16.27225747279543
# Tiempo de ejecución en minutos fue de:  2.2787447690963747
# ...................
# Tiempo total en minutos:  14.122868434588115

# %% [markdown]
# Resultados en configuración SLOW:

# %%
print("El valor original de mérito es: ", merit_0)
print("Tiempo de ejecución en minutos fue de: ", time0/60)
print("...................")
print("Gen 1(con modal sum y geometrías simples)")
print("El mejor mérito es: ", merit_gen1)
print("Tiempo de ejecución en minutos fue de: ", time1/60)
print("...................")
print("Gen 2 (con FEM Source hasta 150 Hz | res=2)")
print("El mejor mérito es ", merits_g2[0])
print("Tiempo de ejecución en minutos fue de: ", time2/60)
print("...................")
print("Gen 3 (con FEM Source hasta 180 Hz | res=2)")
print("El mejor mérito es ", merits_g3[0])
print("Tiempo de ejecución en minutos fue de: ", time3/60)
print("...................")
print("Gen 4 (con FEM Source hasta 200 Hz | res=1)")
print("El mejor mérito es ", merits_g4[0])
print("Tiempo de ejecución en minutos fue de: ", time4/60)
print("...................")
print("Tiempo total en minutos: ", (time0 + time1 + time2 + time3 + time4)/60)
# Out:
# El valor original de mérito es:  (16.524101304062047, 13.19659279917218, 3.327508504889866)
# Tiempo de ejecución en minutos fue de:  0.8824834942817688
# ...................
# Gen 1(con modal sum y geometrías simples)
# El mejor mérito es:  (14.460641013747118, 11.691872904524383, 2.7687681092227345)
# Tiempo de ejecución en minutos fue de:  0.13858884970347088
# ...................
# Gen 2 (con FEM Source hasta 150 Hz | res=2)
# El mejor mérito es  9.72312722502235
# Tiempo de ejecución en minutos fue de:  11.242233184973399
# ...................
# Gen 3 (con FEM Source hasta 180 Hz | res=2)
# El mejor mérito es  11.330954842720583
# Tiempo de ejecución en minutos fue de:  4.392365837097168
# ...................
# Gen 4 (con FEM Source hasta 200 Hz | res=1)
# El mejor mérito es  12.516921704969567
# Tiempo de ejecución en minutos fue de:  6.251231865088145
# ...................
# Tiempo total en minutos:  22.90690323114395

# %% [markdown]
# Acá en el método slow encontro una buena solución, el tema es que recién encontró la solución cuando lo ejecute una segunda vez. Es decir, esta pesando más la heurística de la generación 2 de que justo se genere una sala buena, porque si no encuentra en esa generación una sala que tenga un merito de 9 dB después no mejora, porque los cambios entre las generaciones para las 3 versiones es bastante constante.

# %% [markdown]
# ## Grafico los resultados de la versión SLOW

# %% [markdown]
# Gráfico la rta base y la mejor respuesta de la versión SLOW

# %%
import numpy as np
import matplotlib.pyplot as plt

res_freq = 1
freqs = np.arange(20, 200, res_freq)

plt.figure("Resultado magnitud", figsize=(10, 4))
plt.plot(freqs, mag0, '--', label= "Room base")
plt.plot(freqs, mag_g4[0], '--', label= "Best room")
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude (dB)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Cuarto original

# %%
from plots.graph_room_outline import plot_outline_simple

plot_outline_simple(Lx, Ly, Dx, Dy, Lx_new, Ly_new)

# %%
from plots.graph_room_outline import plot_room_outline

plot_room_outline(Lx_new * 100, Ly_new * 100, Dx_new *100, Dy_new * 100, new_source_pos, new_receptor_pos, best_rooms_g4[0], "Mejor cuarto")

# %%
best_rooms_g4[0]
# Out:
# array([[0.9625, 0.    ],
#        [0.    , 0.63  ],
#        [0.09  , 2.61  ],
#        [0.525 , 3.    ],
#        [1.575 , 3.    ],
#        [2.01  , 2.61  ],
#        [2.1   , 0.63  ],
#        [1.1375, 0.    ]])

# %%
best_rooms_g4[1]
# Out:
# array([[0.93972955, 0.01759555],
#        [0.        , 0.63      ],
#        [0.09      , 2.61      ],
#        [0.55613727, 3.04363216],
#        [1.54386273, 3.04363216],
#        [2.01      , 2.61      ],
#        [2.1       , 0.63      ],
#        [1.16027045, 0.01759555]])

# %%
print(Lx_new)
print(Ly_new)
print(Dx_new)
print(Dy_new)
print(new_source_pos)
print(new_receptor_pos)
# Out:
# 2.1054216337775467
# 3
# 0.20271081688877324
# 0.6000000000000001
# (1.7027108168887732, 1.0, 1.3)
# (1.0527108168887733, 1.9, 1.2)
