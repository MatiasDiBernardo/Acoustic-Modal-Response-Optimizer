# %% [markdown]
# ## Se prueba la optimización random (fuerza bruta)

# %% [markdown]
# Usamos la sala de prueba 1 (versión usando resolución de 2 Hz para encontrar la mejor sala).

# %%
import os
import time
os.chdir('..')

# %%
from room.geometry_generator import calculation_of_geometry
from mesh.mesh_3D_complex import create_complex_mesh
from FEM.FEM_source import FEM_Source_Solver_Average
from aux.merit_figure import merit_magnitude_deviation, merit_spatial_deviation
from plots.graph_room_outline import plot_room_outline

import numpy as np
import matplotlib.pyplot as plt
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Definimos el cuarto
Lx = 250       # Largo de la sala en X 
Ly = 300       # Largo de la sala en Y
Lz = 220       # Alto de la sala
Dx = 50        # Delta X
Dy = 80        # Delta Y
Dz = 10        # Delta Z

# Posiciones fuente y receptor (en metros)
source_position = (1.9, 1.0, 1.3)
receptor_position = (1.25, 1.9, 1.2)

# %%
# Parametros de control
N = 250        # Densidad de la grilla del generador de geometrías
M = 200        # Cantidad de salas a generar
n_walls = 2    # Número de cortes en las paredes
res_freq = 2

# %%
# Almacenar toda la data
start_time = time.time()
rooms = calculation_of_geometry(Lx, Ly, Dx, Dy, N, M, n_walls)
mesh = "room_mesh_complex"  # Crear malla con el script correspondiente
mesh1 = "room_mesh_complex1"  # Crear malla con el script correspondiente
mesh2 = "room_mesh_complex2"  # Crear malla con el script correspondiente
mesh3 = "room_mesh_complex3"  # Crear malla con el script correspondiente
mag_responses = []
merit_sv_values = []
merit_md_values = []

# Itera y almacena los valores para encontrar el mejor cuarto
for i in range(M):
    print("Vamos por el room: ", i)
    print("Vamos por el room: ", i)
    print("Vamos por el room: ", i)
    print("Vamos por el room: ", i)
    print("Vamos por el room: ", i)
    print("Vamos por el room: ", i)
    print("Vamos por el room: ", i)

    # Crea la malla de la geometría selecionada
    Z = (Lz - np.random.uniform(0, Dz))/100
    create_complex_mesh(rooms[i], Z, source_position, 80, mesh1)
    create_complex_mesh(rooms[i], Z, source_position, 140, mesh2)
    create_complex_mesh(rooms[i], Z, source_position, 200, mesh3)

    # Evalua la rta en frecuencia para esa sala
    f1 = np.arange(20, 80, res_freq)
    res1 = FEM_Source_Solver_Average(f1, f'mallado/{mesh1}.msh', receptor_position)

    f2 = np.arange(80, 140, res_freq)
    res2 = FEM_Source_Solver_Average(f2, f'mallado/{mesh2}.msh', receptor_position)

    f3 = np.arange(140, 200, res_freq)
    res3 = FEM_Source_Solver_Average(f3, f'mallado/{mesh3}.msh', receptor_position)

    res_tot = np.hstack([res1, res2, res3])
    res_tot_prom = np.sum(res_tot, axis=0) / 7

    # Calcula figuras de mérito
    sv_merit = merit_spatial_deviation(res_tot)
    md_merit = merit_magnitude_deviation(res_tot)
    
    merit_sv_values.append(sv_merit)
    merit_md_values.append(md_merit)
    mag_responses.append(res_tot_prom)

f_tot =  np.hstack([f1, f2, f3])
merit_sv_values = np.array(merit_sv_values)
merit_md_values = np.array(merit_md_values)
merit_general = merit_md_values + merit_sv_values

idx_best_room = np.argmin(merit_general)
idx_worst_room = np.argmax(merit_general)

best_room_mag = mag_responses[idx_best_room]
worst_room_mag = mag_responses[idx_worst_room]
random_room_mag = mag_responses[np.random.randint(0, M - 1)]
# Out:
# Vamos por el room:  0
# Vamos por el room:  0
# Vamos por el room:  0
# Vamos por el room:  0
# Vamos por el room:  0
# Vamos por el room:  0
# Vamos por el room:  0
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 509 nodes
# Info    : 2710 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1337 nodes
# Info    : 7443 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4162 nodes
# Info    : 24461 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  1
# Vamos por el room:  1
# Vamos por el room:  1
# Vamos por el room:  1
# Vamos por el room:  1
# Vamos por el room:  1
# Vamos por el room:  1
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 522 nodes
# Info    : 2788 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1620 nodes
# Info    : 9154 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5224 nodes
# Info    : 30818 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  2
# Vamos por el room:  2
# Vamos por el room:  2
# Vamos por el room:  2
# Vamos por el room:  2
# Vamos por el room:  2
# Vamos por el room:  2
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 442 nodes
# Info    : 2308 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1117 nodes
# Info    : 6128 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3431 nodes
# Info    : 19934 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  3
# Vamos por el room:  3
# Vamos por el room:  3
# Vamos por el room:  3
# Vamos por el room:  3
# Vamos por el room:  3
# Vamos por el room:  3
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 62 entities
# Info    : 644 nodes
# Info    : 3532 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1211 nodes
# Info    : 6700 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3919 nodes
# Info    : 22902 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  4
# Vamos por el room:  4
# Vamos por el room:  4
# Vamos por el room:  4
# Vamos por el room:  4
# Vamos por el room:  4
# Vamos por el room:  4
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 441 nodes
# Info    : 2322 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1380 nodes
# Info    : 7742 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4477 nodes
# Info    : 26394 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  5
# Vamos por el room:  5
# Vamos por el room:  5
# Vamos por el room:  5
# Vamos por el room:  5
# Vamos por el room:  5
# Vamos por el room:  5
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 429 nodes
# Info    : 2218 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1450 nodes
# Info    : 8082 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4637 nodes
# Info    : 27277 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  6
# Vamos por el room:  6
# Vamos por el room:  6
# Vamos por el room:  6
# Vamos por el room:  6
# Vamos por el room:  6
# Vamos por el room:  6
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 502 nodes
# Info    : 2680 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1449 nodes
# Info    : 8079 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4461 nodes
# Info    : 26325 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  7
# Vamos por el room:  7
# Vamos por el room:  7
# Vamos por el room:  7
# Vamos por el room:  7
# Vamos por el room:  7
# Vamos por el room:  7
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 466 nodes
# Info    : 2471 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1117 nodes
# Info    : 6097 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3227 nodes
# Info    : 18730 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  8
# Vamos por el room:  8
# Vamos por el room:  8
# Vamos por el room:  8
# Vamos por el room:  8
# Vamos por el room:  8
# Vamos por el room:  8
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 327 nodes
# Info    : 1677 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1183 nodes
# Info    : 6462 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3435 nodes
# Info    : 19940 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  9
# Vamos por el room:  9
# Vamos por el room:  9
# Vamos por el room:  9
# Vamos por el room:  9
# Vamos por el room:  9
# Vamos por el room:  9
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 441 nodes
# Info    : 2313 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1170 nodes
# Info    : 6388 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3639 nodes
# Info    : 21109 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  10
# Vamos por el room:  10
# Vamos por el room:  10
# Vamos por el room:  10
# Vamos por el room:  10
# Vamos por el room:  10
# Vamos por el room:  10
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 386 nodes
# Info    : 2008 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1076 nodes
# Info    : 5880 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3412 nodes
# Info    : 19838 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  11
# Vamos por el room:  11
# Vamos por el room:  11
# Vamos por el room:  11
# Vamos por el room:  11
# Vamos por el room:  11
# Vamos por el room:  11
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 522 nodes
# Info    : 2780 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1461 nodes
# Info    : 8171 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4667 nodes
# Info    : 27465 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  12
# Vamos por el room:  12
# Vamos por el room:  12
# Vamos por el room:  12
# Vamos por el room:  12
# Vamos por el room:  12
# Vamos por el room:  12
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 542 nodes
# Info    : 2896 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1573 nodes
# Info    : 8859 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5013 nodes
# Info    : 29643 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  13
# Vamos por el room:  13
# Vamos por el room:  13
# Vamos por el room:  13
# Vamos por el room:  13
# Vamos por el room:  13
# Vamos por el room:  13
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 492 nodes
# Info    : 2616 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1435 nodes
# Info    : 7991 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4462 nodes
# Info    : 26305 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  14
# Vamos por el room:  14
# Vamos por el room:  14
# Vamos por el room:  14
# Vamos por el room:  14
# Vamos por el room:  14
# Vamos por el room:  14
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 478 nodes
# Info    : 2512 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1270 nodes
# Info    : 7063 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4068 nodes
# Info    : 23912 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  15
# Vamos por el room:  15
# Vamos por el room:  15
# Vamos por el room:  15
# Vamos por el room:  15
# Vamos por el room:  15
# Vamos por el room:  15
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 62 entities
# Info    : 853 nodes
# Info    : 4734 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1130 nodes
# Info    : 6212 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4058 nodes
# Info    : 23940 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  16
# Vamos por el room:  16
# Vamos por el room:  16
# Vamos por el room:  16
# Vamos por el room:  16
# Vamos por el room:  16
# Vamos por el room:  16
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 511 nodes
# Info    : 2695 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1534 nodes
# Info    : 8587 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5371 nodes
# Info    : 31809 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  17
# Vamos por el room:  17
# Vamos por el room:  17
# Vamos por el room:  17
# Vamos por el room:  17
# Vamos por el room:  17
# Vamos por el room:  17
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 62 entities
# Info    : 782 nodes
# Info    : 4329 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1234 nodes
# Info    : 6798 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3774 nodes
# Info    : 22184 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  18
# Vamos por el room:  18
# Vamos por el room:  18
# Vamos por el room:  18
# Vamos por el room:  18
# Vamos por el room:  18
# Vamos por el room:  18
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 62 entities
# Info    : 618 nodes
# Info    : 3362 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1062 nodes
# Info    : 5813 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3260 nodes
# Info    : 18881 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  19
# Vamos por el room:  19
# Vamos por el room:  19
# Vamos por el room:  19
# Vamos por el room:  19
# Vamos por el room:  19
# Vamos por el room:  19
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 62 entities
# Info    : 664 nodes
# Info    : 3633 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1194 nodes
# Info    : 6597 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3404 nodes
# Info    : 19837 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  20
# Vamos por el room:  20
# Vamos por el room:  20
# Vamos por el room:  20
# Vamos por el room:  20
# Vamos por el room:  20
# Vamos por el room:  20
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 425 nodes
# Info    : 2170 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1096 nodes
# Info    : 5987 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3359 nodes
# Info    : 19424 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  21
# Vamos por el room:  21
# Vamos por el room:  21
# Vamos por el room:  21
# Vamos por el room:  21
# Vamos por el room:  21
# Vamos por el room:  21
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 407 nodes
# Info    : 2126 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1062 nodes
# Info    : 5808 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3409 nodes
# Info    : 19853 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  22
# Vamos por el room:  22
# Vamos por el room:  22
# Vamos por el room:  22
# Vamos por el room:  22
# Vamos por el room:  22
# Vamos por el room:  22
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 479 nodes
# Info    : 2532 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1332 nodes
# Info    : 7324 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4249 nodes
# Info    : 25044 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  23
# Vamos por el room:  23
# Vamos por el room:  23
# Vamos por el room:  23
# Vamos por el room:  23
# Vamos por el room:  23
# Vamos por el room:  23
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 480 nodes
# Info    : 2501 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1195 nodes
# Info    : 6521 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3809 nodes
# Info    : 22228 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  24
# Vamos por el room:  24
# Vamos por el room:  24
# Vamos por el room:  24
# Vamos por el room:  24
# Vamos por el room:  24
# Vamos por el room:  24
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 403 nodes
# Info    : 2127 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1299 nodes
# Info    : 7183 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4339 nodes
# Info    : 25494 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  25
# Vamos por el room:  25
# Vamos por el room:  25
# Vamos por el room:  25
# Vamos por el room:  25
# Vamos por el room:  25
# Vamos por el room:  25
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 62 entities
# Info    : 583 nodes
# Info    : 3118 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1055 nodes
# Info    : 5766 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3269 nodes
# Info    : 18991 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  26
# Vamos por el room:  26
# Vamos por el room:  26
# Vamos por el room:  26
# Vamos por el room:  26
# Vamos por el room:  26
# Vamos por el room:  26
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 515 nodes
# Info    : 2753 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1457 nodes
# Info    : 8115 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4664 nodes
# Info    : 27589 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  27
# Vamos por el room:  27
# Vamos por el room:  27
# Vamos por el room:  27
# Vamos por el room:  27
# Vamos por el room:  27
# Vamos por el room:  27
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 390 nodes
# Info    : 2047 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1304 nodes
# Info    : 7244 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3934 nodes
# Info    : 23012 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  28
# Vamos por el room:  28
# Vamos por el room:  28
# Vamos por el room:  28
# Vamos por el room:  28
# Vamos por el room:  28
# Vamos por el room:  28
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 420 nodes
# Info    : 2177 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1276 nodes
# Info    : 7057 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4325 nodes
# Info    : 25391 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  29
# Vamos por el room:  29
# Vamos por el room:  29
# Vamos por el room:  29
# Vamos por el room:  29
# Vamos por el room:  29
# Vamos por el room:  29
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 62 entities
# Info    : 687 nodes
# Info    : 3742 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1295 nodes
# Info    : 7045 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4500 nodes
# Info    : 26459 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  30
# Vamos por el room:  30
# Vamos por el room:  30
# Vamos por el room:  30
# Vamos por el room:  30
# Vamos por el room:  30
# Vamos por el room:  30
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 474 nodes
# Info    : 2528 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1349 nodes
# Info    : 7465 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4332 nodes
# Info    : 25477 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  31
# Vamos por el room:  31
# Vamos por el room:  31
# Vamos por el room:  31
# Vamos por el room:  31
# Vamos por el room:  31
# Vamos por el room:  31
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 439 nodes
# Info    : 2314 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1149 nodes
# Info    : 6326 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3519 nodes
# Info    : 20569 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  32
# Vamos por el room:  32
# Vamos por el room:  32
# Vamos por el room:  32
# Vamos por el room:  32
# Vamos por el room:  32
# Vamos por el room:  32
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 444 nodes
# Info    : 2345 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1378 nodes
# Info    : 7659 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4126 nodes
# Info    : 24196 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  33
# Vamos por el room:  33
# Vamos por el room:  33
# Vamos por el room:  33
# Vamos por el room:  33
# Vamos por el room:  33
# Vamos por el room:  33
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 488 nodes
# Info    : 2575 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1412 nodes
# Info    : 7799 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4793 nodes
# Info    : 28314 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  34
# Vamos por el room:  34
# Vamos por el room:  34
# Vamos por el room:  34
# Vamos por el room:  34
# Vamos por el room:  34
# Vamos por el room:  34
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(f"El valor de mértio mínimo es: {merit_general[idx_best_room]} | Con SV: {merit_sv_values[idx_best_room]} | Con MD: {merit_md_values[idx_best_room]}" )
print("............................")
print(f"El peor valor de mérito es: {merit_general[idx_worst_room]} | Con SV: {merit_sv_values[idx_worst_room]} | Con MD: {merit_md_values[idx_worst_room]}" )
print("............................")
print("El valor de mértio promedio es: ", np.mean(merit_general))
print("............................")
print("El tiempo de ejecución en minutos fue de: ", (time.time() - start_time)/60)
# Out:
# El valor de mértio mínimo es: 13.828766134073337 | Con SV: 3.066535308611067 | Con MD: 10.76223082546227
# ............................
# El peor valor de mérito es: 21.896374070936695 | Con SV: 5.962805411965385 | Con MD: 15.93356865897131
# ............................
# El valor de mértio promedio es:  17.12061179341233
# ............................
# El tiempo de ejecución en minutos fue de:  23.424754424889883

# %% [markdown]
# Ahora se compara la mejor sala evaluada con resolución de 1 Hz

# %%
from complex_outline_optim import solve_complex_geom

merit_res, mag_res = solve_complex_geom(Lx/100, Ly/100, Lz/100, Dx/100, Dy/100, source_position, receptor_position, rooms[idx_best_room])
merit_res
# Out:
# /home/diber/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 from complex_outline_optim import solve_complex_geom
# ----> 3 merit_res, mag_res = solve_complex_geom(Lx/100, Ly/100, Lz/100, Dx/100, Dy/100, source_position, receptor_position, rooms[idx_best_room])
#
# NameError: name 'Lx' is not defined

# %% [markdown]
# Comparación entre las dos respuestas (en frecuencia)

# %%
from complex_outline_optim import calculate_initial

merit_0, mag0 = calculate_initial(Lx/100, Ly/100, Lz/100, source_position, receptor_position)
freq_base = np.arange(20, 200, 1)
# Out:
# Info    : Reading 'mallado/room_base_optim1.msh'...
# Info    : 33 entities
# Info    : 705 nodes
# Info    : 3928 elements
# Info    : Done reading 'mallado/room_base_optim1.msh'
# Radio de la esfera fuente detectado automáticamente: 0.0904+0.0000j m
# Info    : Reading 'mallado/room_base_optim2.msh'...
# Info    : 33 entities
# Info    : 1858 nodes
# Info    : 10518 elements
# Info    : Done reading 'mallado/room_base_optim2.msh'
# Radio de la esfera fuente detectado automáticamente: 0.0904+0.0000j m
# Info    : Reading 'mallado/room_base_optim3.msh'...
# Info    : 33 entities
# Info    : 6201 nodes
# Info    : 36807 elements
# Info    : Done reading 'mallado/room_base_optim3.msh'
# Radio de la esfera fuente detectado automáticamente: 0.0904+0.0000j m

# %%
from plots.graph_mag_response import mag_response_comparison

freqs_res1 = np.arange(20, 200, 1)
mags = [(freqs_res1, mag0, "Respuesta base")]
mag_response_comparison(mags)

# %%
plt.figure("Resultado magnitud")
plt.plot(f_tot, best_room_mag, label= "Best Modal Dist")
plt.plot(f_tot, worst_room_mag, label= "Worst Modal Dist")
plt.plot(f_tot, random_room_mag, label= "Random Modal Dist")
plt.xlabel('Frecuencia (Hz)')
plt.ylabel('Amplitud (dB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plot_room_outline(Lx, Ly, Dx, Dy, source_position, receptor_position, rooms[idx_best_room], "Distribución mejor cuarto")
plot_room_outline(Lx, Ly, Dx, Dy, source_position, receptor_position, rooms[idx_worst_room], "Distribución peor cuarto")

print("La mejor sala es: ", rooms[idx_best_room])
print("............................")
print("La peor sala es: ", rooms[idx_worst_room])
# Out:
# La mejor sala es:  [[0.9375     0.        ]
#  [0.         0.44      ]
#  [0.11       2.64      ]
#  [0.83333333 3.        ]
#  [1.66666667 3.        ]
#  [2.39       2.64      ]
#  [2.5        0.44      ]
#  [1.5625     0.        ]]
# ............................
# La peor sala es:  [[0.9375     0.        ]
#  [0.11       0.55      ]
#  [0.         1.87      ]
#  [0.83333333 3.        ]
#  [1.66666667 3.        ]
#  [2.5        1.87      ]
#  [2.39       0.55      ]
#  [1.5625     0.        ]]
