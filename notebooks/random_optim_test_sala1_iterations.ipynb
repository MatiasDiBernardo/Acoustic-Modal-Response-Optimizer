# %% [markdown]
# ## Se prueba la optimización random (fuerza bruta) y se cambia el numero de salas a iterar

# %% [markdown]
# Usamos la sala de prueba 1

# %%
import os
import time
os.chdir('..')

# %%
from room.geometry_generator import calculation_of_geometry
from mesh.mesh_3D_complex import create_complex_mesh
from FEM.FEM_source import FEM_Source_Solver_Average
from aux.merit_figure import merit_magnitude_deviation, merit_spatial_deviation
from plots.graph_room_outline import plot_room_outline

import numpy as np
import matplotlib.pyplot as plt
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Definimos el cuarto
Lx = 250       # Largo de la sala en X 
Ly = 300       # Largo de la sala en Y
Lz = 220       # Alto de la sala
Dx = 50        # Delta X
Dy = 80        # Delta Y
Dz = 10        # Delta Z

# Posiciones fuente y receptor (en metros)
source_position = (1.9, 1.0, 1.3)
receptor_position = (1.25, 1.9, 1.2)

# %%
# Parametros de control
N = 250        # Densidad de la grilla del generador de geometrías
M = 300      # Cantidad de salas a generar
n_walls = 2    # Número de cortes en las paredes
res_freq = 1

# %%
# Almacenar toda la data
start_time = time.time()
rooms = calculation_of_geometry(Lx, Ly, Dx, Dy, N, M, n_walls)
mesh = "room_mesh_complex"  # Crear malla con el script correspondiente
mesh1 = "room_mesh_complex1"  # Crear malla con el script correspondiente
mesh2 = "room_mesh_complex2"  # Crear malla con el script correspondiente
mesh3 = "room_mesh_complex3"  # Crear malla con el script correspondiente
mag_responses = []
merit_sv_values = []
merit_md_values = []

# Itera y almacena los valores para encontrar el mejor cuarto
for i in range(M):
    print("Vamos por el room: ", i)

    # Crea la malla de la geometría selecionada
    Z = (Lz - np.random.uniform(0, Dz))/100
    create_complex_mesh(rooms[i], Z, source_position, 80, mesh1)
    create_complex_mesh(rooms[i], Z, source_position, 140, mesh2)
    create_complex_mesh(rooms[i], Z, source_position, 200, mesh3)

    # Evalua la rta en frecuencia para esa sala
    f1 = np.arange(20, 80, res_freq)
    res1 = FEM_Source_Solver_Average(f1, f'mallado/{mesh1}.msh', receptor_position)

    f2 = np.arange(80, 140, res_freq)
    res2 = FEM_Source_Solver_Average(f2, f'mallado/{mesh2}.msh', receptor_position)

    f3 = np.arange(140, 200, res_freq)
    res3 = FEM_Source_Solver_Average(f3, f'mallado/{mesh3}.msh', receptor_position)

    res_tot = np.hstack([res1, res2, res3])
    res_tot_prom = np.sum(res_tot, axis=0) / 7

    # Calcula figuras de mérito
    sv_merit = merit_spatial_deviation(res_tot)
    md_merit = merit_magnitude_deviation(res_tot)
    
    merit_sv_values.append(sv_merit)
    merit_md_values.append(md_merit)
    mag_responses.append(res_tot_prom)

f_tot =  np.hstack([f1, f2, f3])
merit_sv_values = np.array(merit_sv_values)
merit_md_values = np.array(merit_md_values)
merit_general = merit_md_values + merit_sv_values

idx_best_room = np.argmin(merit_general)
idx_worst_room = np.argmax(merit_general)

best_room_mag = mag_responses[idx_best_room]
worst_room_mag = mag_responses[idx_worst_room]
random_room_mag = mag_responses[np.random.randint(0, M - 1)]
# Out:
# Vamos por el room:  0
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 542 nodes
# Info    : 2870 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1530 nodes
# Info    : 8566 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4887 nodes
# Info    : 28807 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  1
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 459 nodes
# Info    : 2360 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1397 nodes
# Info    : 7682 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4658 nodes
# Info    : 27352 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  2
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 443 nodes
# Info    : 2326 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1391 nodes
# Info    : 7702 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4436 nodes
# Info    : 26053 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  3
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 581 nodes
# Info    : 3107 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1560 nodes
# Info    : 8762 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5118 nodes
# Info    : 30304 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  4
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 470 nodes
# Info    : 2440 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1376 nodes
# Info    : 7543 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4239 nodes
# Info    : 24767 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  5
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 529 nodes
# Info    : 2811 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1276 nodes
# Info    : 7091 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4366 nodes
# Info    : 25606 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  6
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 427 nodes
# Info    : 2217 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1432 nodes
# Info    : 7897 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5022 nodes
# Info    : 29538 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  7
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 556 nodes
# Info    : 2964 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1578 nodes
# Info    : 8913 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5100 nodes
# Info    : 30027 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  8
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 45 entities
# Info    : 444 nodes
# Info    : 2344 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 45 entities
# Info    : 1270 nodes
# Info    : 7012 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 45 entities
# Info    : 4191 nodes
# Info    : 24582 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  9
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 400 nodes
# Info    : 1998 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1226 nodes
# Info    : 6600 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3974 nodes
# Info    : 22989 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  10
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 468 nodes
# Info    : 2459 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1331 nodes
# Info    : 7386 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4222 nodes
# Info    : 24710 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  11
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 410 nodes
# Info    : 2115 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1319 nodes
# Info    : 7262 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4064 nodes
# Info    : 23749 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  12
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 62 entities
# Info    : 572 nodes
# Info    : 2991 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1252 nodes
# Info    : 6795 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4101 nodes
# Info    : 23804 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  13
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 448 nodes
# Info    : 2319 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1328 nodes
# Info    : 7314 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4115 nodes
# Info    : 23864 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  14
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 522 nodes
# Info    : 2767 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1621 nodes
# Info    : 9079 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5106 nodes
# Info    : 30110 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  15
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 451 nodes
# Info    : 2374 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1510 nodes
# Info    : 8390 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5148 nodes
# Info    : 30380 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  16
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 368 nodes
# Info    : 1889 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1283 nodes
# Info    : 7045 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4240 nodes
# Info    : 24898 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  17
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 656 nodes
# Info    : 3535 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1698 nodes
# Info    : 9593 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5754 nodes
# Info    : 34193 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  18
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 537 nodes
# Info    : 2823 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1680 nodes
# Info    : 9455 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5621 nodes
# Info    : 33313 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  19
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 67 entities
# Info    : 733 nodes
# Info    : 3988 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1357 nodes
# Info    : 7427 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4176 nodes
# Info    : 24222 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  20
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 538 nodes
# Info    : 2865 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1590 nodes
# Info    : 8892 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5116 nodes
# Info    : 30239 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  21
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 499 nodes
# Info    : 2642 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1380 nodes
# Info    : 7672 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4577 nodes
# Info    : 26992 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  22
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 383 nodes
# Info    : 1947 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1361 nodes
# Info    : 7504 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4165 nodes
# Info    : 24297 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  23
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 490 nodes
# Info    : 2557 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1576 nodes
# Info    : 8760 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5133 nodes
# Info    : 30283 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  24
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 541 nodes
# Info    : 2851 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1469 nodes
# Info    : 8219 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4571 nodes
# Info    : 26760 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  25
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 401 nodes
# Info    : 2076 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1437 nodes
# Info    : 8034 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4602 nodes
# Info    : 27094 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  26
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 581 nodes
# Info    : 3089 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1783 nodes
# Info    : 10048 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6084 nodes
# Info    : 36090 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  27
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 631 nodes
# Info    : 3382 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1553 nodes
# Info    : 8624 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4976 nodes
# Info    : 29309 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  28
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 62 entities
# Info    : 577 nodes
# Info    : 3090 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1213 nodes
# Info    : 6600 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3641 nodes
# Info    : 21186 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  29
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 445 nodes
# Info    : 2309 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1510 nodes
# Info    : 8443 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4886 nodes
# Info    : 28794 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  30
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 67 entities
# Info    : 790 nodes
# Info    : 4339 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1267 nodes
# Info    : 6932 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4328 nodes
# Info    : 25234 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  31
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 490 nodes
# Info    : 2545 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1485 nodes
# Info    : 8317 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4727 nodes
# Info    : 27708 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  32
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 420 nodes
# Info    : 2187 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1351 nodes
# Info    : 7465 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4233 nodes
# Info    : 24760 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  33
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 67 entities
# Info    : 658 nodes
# Info    : 3531 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1432 nodes
# Info    : 7878 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4887 nodes
# Info    : 28713 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  34
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 507 nodes
# Info    : 2685 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1472 nodes
# Info    : 8181 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4586 nodes
# Info    : 27066 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  35
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 619 nodes
# Info    : 3303 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1527 nodes
# Info    : 8526 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4661 nodes
# Info    : 27469 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  36
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 435 nodes
# Info    : 2261 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1328 nodes
# Info    : 7339 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3986 nodes
# Info    : 23176 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  37
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 442 nodes
# Info    : 2328 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1413 nodes
# Info    : 7833 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4391 nodes
# Info    : 25642 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  38
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 446 nodes
# Info    : 2332 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1462 nodes
# Info    : 8080 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4947 nodes
# Info    : 29312 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  39
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 425 nodes
# Info    : 2210 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1315 nodes
# Info    : 7220 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4416 nodes
# Info    : 25860 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  40
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 422 nodes
# Info    : 2191 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1399 nodes
# Info    : 7694 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4126 nodes
# Info    : 24080 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  41
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 463 nodes
# Info    : 2440 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1593 nodes
# Info    : 8995 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5191 nodes
# Info    : 30530 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  42
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 388 nodes
# Info    : 1991 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1328 nodes
# Info    : 7376 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4529 nodes
# Info    : 26574 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  43
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 486 nodes
# Info    : 2553 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1369 nodes
# Info    : 7587 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4433 nodes
# Info    : 26075 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  44
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 506 nodes
# Info    : 2680 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1650 nodes
# Info    : 9251 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5173 nodes
# Info    : 30686 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  45
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 486 nodes
# Info    : 2565 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1573 nodes
# Info    : 8767 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5161 nodes
# Info    : 30560 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  46
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 528 nodes
# Info    : 2780 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1774 nodes
# Info    : 9999 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5865 nodes
# Info    : 34714 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  47
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 538 nodes
# Info    : 2843 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1469 nodes
# Info    : 8144 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4801 nodes
# Info    : 28269 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  48
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 62 entities
# Info    : 594 nodes
# Info    : 3126 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1330 nodes
# Info    : 7271 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4003 nodes
# Info    : 23250 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  49
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 474 nodes
# Info    : 2490 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1383 nodes
# Info    : 7590 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4230 nodes
# Info    : 24796 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  50
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 500 nodes
# Info    : 2626 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1547 nodes
# Info    : 8639 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4979 nodes
# Info    : 29301 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  51
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 500 nodes
# Info    : 2629 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1457 nodes
# Info    : 8158 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4701 nodes
# Info    : 27767 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  52
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 526 nodes
# Info    : 2786 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1686 nodes
# Info    : 9460 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5413 nodes
# Info    : 32114 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  53
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 612 nodes
# Info    : 3252 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1608 nodes
# Info    : 9132 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5566 nodes
# Info    : 32928 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  54
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 441 nodes
# Info    : 2283 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1437 nodes
# Info    : 7984 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4768 nodes
# Info    : 27877 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  55
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 479 nodes
# Info    : 2495 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1323 nodes
# Info    : 7291 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4302 nodes
# Info    : 25077 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  56
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 531 nodes
# Info    : 2818 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1479 nodes
# Info    : 8241 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4647 nodes
# Info    : 27394 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  57
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 460 nodes
# Info    : 2426 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1314 nodes
# Info    : 7197 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4260 nodes
# Info    : 24957 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  58
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 445 nodes
# Info    : 2337 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1439 nodes
# Info    : 8036 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4559 nodes
# Info    : 26828 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  59
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 416 nodes
# Info    : 2144 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1349 nodes
# Info    : 7481 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4175 nodes
# Info    : 24451 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  60
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 537 nodes
# Info    : 2848 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1626 nodes
# Info    : 9116 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5432 nodes
# Info    : 31947 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  61
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 446 nodes
# Info    : 2306 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1560 nodes
# Info    : 8725 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5370 nodes
# Info    : 31902 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  62
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 435 nodes
# Info    : 2243 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1223 nodes
# Info    : 6685 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3884 nodes
# Info    : 22674 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  63
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 436 nodes
# Info    : 2259 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1441 nodes
# Info    : 8017 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4703 nodes
# Info    : 27492 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  64
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 473 nodes
# Info    : 2468 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1447 nodes
# Info    : 7989 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4953 nodes
# Info    : 29284 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  65
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 517 nodes
# Info    : 2716 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1519 nodes
# Info    : 8489 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4255 nodes
# Info    : 24874 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  66
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 409 nodes
# Info    : 2094 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1307 nodes
# Info    : 7208 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4418 nodes
# Info    : 26010 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  67
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 598 nodes
# Info    : 3189 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1546 nodes
# Info    : 8664 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5033 nodes
# Info    : 29738 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  68
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 670 nodes
# Info    : 3645 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1503 nodes
# Info    : 8401 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5037 nodes
# Info    : 29765 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  69
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 640 nodes
# Info    : 3461 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1390 nodes
# Info    : 7777 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4545 nodes
# Info    : 26855 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  70
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 478 nodes
# Info    : 2507 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1359 nodes
# Info    : 7525 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4130 nodes
# Info    : 24156 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  71
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 536 nodes
# Info    : 2846 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1493 nodes
# Info    : 8274 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4769 nodes
# Info    : 28146 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  72
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 508 nodes
# Info    : 2665 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1450 nodes
# Info    : 8074 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4643 nodes
# Info    : 27385 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  73
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 559 nodes
# Info    : 2941 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1458 nodes
# Info    : 8066 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4834 nodes
# Info    : 28462 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  74
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 473 nodes
# Info    : 2477 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1547 nodes
# Info    : 8600 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4844 nodes
# Info    : 28353 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  75
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 457 nodes
# Info    : 2386 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1409 nodes
# Info    : 7868 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4737 nodes
# Info    : 27833 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  76
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 512 nodes
# Info    : 2679 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1394 nodes
# Info    : 7681 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4600 nodes
# Info    : 26858 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  77
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 456 nodes
# Info    : 2379 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1381 nodes
# Info    : 7622 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4352 nodes
# Info    : 25294 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  78
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 463 nodes
# Info    : 2437 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1540 nodes
# Info    : 8595 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5026 nodes
# Info    : 29659 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  79
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 502 nodes
# Info    : 2658 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1743 nodes
# Info    : 9821 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5663 nodes
# Info    : 33644 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  80
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 502 nodes
# Info    : 2636 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1650 nodes
# Info    : 9222 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5897 nodes
# Info    : 35064 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  81
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 598 nodes
# Info    : 3220 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1544 nodes
# Info    : 8605 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4988 nodes
# Info    : 29415 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  82
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 535 nodes
# Info    : 2796 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1501 nodes
# Info    : 8404 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4825 nodes
# Info    : 28433 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  83
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 576 nodes
# Info    : 3081 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1489 nodes
# Info    : 8291 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4695 nodes
# Info    : 27664 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  84
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 591 nodes
# Info    : 3167 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1668 nodes
# Info    : 9457 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5185 nodes
# Info    : 30755 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  85
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 507 nodes
# Info    : 2658 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1390 nodes
# Info    : 7742 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4616 nodes
# Info    : 27078 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  86
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 452 nodes
# Info    : 2360 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1489 nodes
# Info    : 8238 elements
# ...
# Info    : 558 nodes
# Info    : 2947 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1588 nodes
# Info    : 8866 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5013 nodes
# Info    : 29549 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  272
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 545 nodes
# Info    : 2890 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1639 nodes
# Info    : 9220 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5525 nodes
# Info    : 32840 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  273
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 494 nodes
# Info    : 2657 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1672 nodes
# Info    : 9432 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5519 nodes
# Info    : 32670 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  274
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 504 nodes
# Info    : 2650 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1347 nodes
# Info    : 7432 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4101 nodes
# Info    : 23900 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  275
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 473 nodes
# Info    : 2506 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1703 nodes
# Info    : 9576 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5784 nodes
# Info    : 34435 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  276
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 528 nodes
# Info    : 2771 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1581 nodes
# Info    : 8865 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4911 nodes
# Info    : 29066 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  277
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 430 nodes
# Info    : 2227 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1593 nodes
# Info    : 8880 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4798 nodes
# Info    : 28115 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  278
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 514 nodes
# Info    : 2698 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1453 nodes
# Info    : 8085 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4901 nodes
# Info    : 28929 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  279
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 508 nodes
# Info    : 2689 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1578 nodes
# Info    : 8802 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5562 nodes
# Info    : 33053 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  280
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 447 nodes
# Info    : 2317 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1348 nodes
# Info    : 7439 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3985 nodes
# Info    : 23287 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  281
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 570 nodes
# Info    : 3012 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1427 nodes
# Info    : 7935 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4141 nodes
# Info    : 24258 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  282
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 473 nodes
# Info    : 2475 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1527 nodes
# Info    : 8417 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4873 nodes
# Info    : 28669 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  283
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 495 nodes
# Info    : 2564 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1453 nodes
# Info    : 7955 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4568 nodes
# Info    : 26739 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  284
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 389 nodes
# Info    : 1995 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1323 nodes
# Info    : 7330 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4142 nodes
# Info    : 24167 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  285
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 548 nodes
# Info    : 2886 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1563 nodes
# Info    : 8708 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5200 nodes
# Info    : 30700 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  286
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 502 nodes
# Info    : 2644 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1689 nodes
# Info    : 9466 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5121 nodes
# Info    : 30408 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  287
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 405 nodes
# Info    : 2094 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1376 nodes
# Info    : 7574 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4768 nodes
# Info    : 28014 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  288
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 446 nodes
# Info    : 2350 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1395 nodes
# Info    : 7802 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4759 nodes
# Info    : 28051 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  289
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 410 nodes
# Info    : 2107 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1405 nodes
# Info    : 7721 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4335 nodes
# Info    : 25319 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  290
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 441 nodes
# Info    : 2267 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1366 nodes
# Info    : 7564 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4369 nodes
# Info    : 25604 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  291
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 480 nodes
# Info    : 2518 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1364 nodes
# Info    : 7557 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4498 nodes
# Info    : 26348 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  292
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 592 nodes
# Info    : 3154 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1768 nodes
# Info    : 9965 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5966 nodes
# Info    : 35415 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  293
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 470 nodes
# Info    : 2435 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1350 nodes
# Info    : 7457 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4214 nodes
# Info    : 24668 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  294
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 469 nodes
# Info    : 2499 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1353 nodes
# Info    : 7456 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4000 nodes
# Info    : 23467 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  295
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 485 nodes
# Info    : 2543 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1461 nodes
# Info    : 8187 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5064 nodes
# Info    : 29901 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  296
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 503 nodes
# Info    : 2636 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1398 nodes
# Info    : 7766 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4308 nodes
# Info    : 25323 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  297
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 527 nodes
# Info    : 2770 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1694 nodes
# Info    : 9496 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6136 nodes
# Info    : 36553 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  298
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 407 nodes
# Info    : 2093 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1380 nodes
# Info    : 7659 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 4120 nodes
# Info    : 24066 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  299
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 441 nodes
# Info    : 2278 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 1334 nodes
# Info    : 7343 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 3990 nodes
# Info    : 23310 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'

# %% [markdown]
# Resultados con 50 salas (el tiempo fue 13 minutos)

# %%
print(f"El valor de mértio mínimo es: {merit_general[idx_best_room]} | Con SV: {merit_sv_values[idx_best_room]} | Con MD: {merit_md_values[idx_best_room]}" )
print("............................")
print(f"El peor valor de mérito es: {merit_general[idx_worst_room]} | Con SV: {merit_sv_values[idx_worst_room]} | Con MD: {merit_md_values[idx_worst_room]}" )
print("............................")
print("El valor de mértio promedio es: ", np.mean(merit_general))
print("............................")
print("El tiempo de ejecución en minutos fue de: ", (time.time() - start_time)/60)
# Out:
# El valor de mértio mínimo es: 14.436345575990682 | Con SV: 3.525438387451828 | Con MD: 10.910907188538854
# ............................
# El peor valor de mérito es: 18.428043143844953 | Con SV: 3.7854942268289897 | Con MD: 14.642548917015963
# ............................
# El valor de mértio promedio es:  16.328501757772656
# ............................
# El tiempo de ejecución en minutos fue de:  17.482112316290536

# %%
from complex_outline_optim import calculate_initial

merit_0, mag0 = calculate_initial(Lx/100, Ly/100, Lz/100, source_position, receptor_position)
freq_base = np.arange(20, 200, 1)
merit_0
# Out:
# Info    : Reading 'mallado/room_base_optim1.msh'...
# Info    : 33 entities
# Info    : 705 nodes
# Info    : 3928 elements
# Info    : Done reading 'mallado/room_base_optim1.msh'
# Info    : Reading 'mallado/room_base_optim2.msh'...
# Info    : 33 entities
# Info    : 1858 nodes
# Info    : 10518 elements
# Info    : Done reading 'mallado/room_base_optim2.msh'
# Info    : Reading 'mallado/room_base_optim3.msh'...
# Info    : 33 entities
# Info    : 6201 nodes
# Info    : 36807 elements
# Info    : Done reading 'mallado/room_base_optim3.msh'
# (15.935706884213301, 12.540030814890079, 3.3956760693232226)

# %%
from plots.graph_mag_response import mag_response_comparison

freqs_res1 = np.arange(20, 200, 1)
mags = [(freqs_res1, mag0, "Respuesta base"), (f_tot, best_room_mag, "Mejor respuesta"), (f_tot, worst_room_mag, "Peor Respuesta")]
mag_response_comparison(mags)

# %%
plot_room_outline(Lx, Ly, Dx, Dy, source_position, receptor_position, rooms[idx_best_room], "Distribución mejor cuarto")
plot_room_outline(Lx, Ly, Dx, Dy, source_position, receptor_position, rooms[idx_worst_room], "Distribución peor cuarto")

print("La mejor sala es: ", rooms[idx_best_room])
print("............................")
print("La peor sala es: ", rooms[idx_worst_room])
# Out:
# La mejor sala es:  [[0.10416667 0.        ]
#  [0.99       0.22      ]
#  [0.22       0.33      ]
#  [0.3125     3.        ]
#  [2.1875     3.        ]
#  [2.28       0.33      ]
#  [1.51       0.22      ]
#  [2.39583333 0.        ]]
# ............................
# La peor sala es:  [[0.10416667 0.        ]
#  [0.44       0.55      ]
#  [0.         1.43      ]
#  [0.3125     3.        ]
#  [2.1875     3.        ]
#  [2.5        1.43      ]
#  [2.06       0.55      ]
#  [2.39583333 0.        ]]

# %% [markdown]
# Resultado para 100 salas (tomo 25 minutos)

# %%
print(f"El valor de mértio mínimo es: {merit_general[idx_best_room]} | Con SV: {merit_sv_values[idx_best_room]} | Con MD: {merit_md_values[idx_best_room]}" )
print("............................")
print(f"El peor valor de mérito es: {merit_general[idx_worst_room]} | Con SV: {merit_sv_values[idx_worst_room]} | Con MD: {merit_md_values[idx_worst_room]}" )
print("............................")
print("El valor de mértio promedio es: ", np.mean(merit_general))
print("............................")
print("El tiempo de ejecución en minutos fue de: ", (time.time() - start_time)/60)
# Out:
# El valor de mértio mínimo es: 13.567548586517614 | Con SV: 2.9677190015290256 | Con MD: 10.599829584988589
# ............................
# El peor valor de mérito es: 19.185211554558972 | Con SV: 4.330806464242216 | Con MD: 14.854405090316755
# ............................
# El valor de mértio promedio es:  16.26509630173417
# ............................
# El tiempo de ejecución en minutos fue de:  29.995527883370716

# %%
plot_room_outline(Lx, Ly, Dx, Dy, source_position, receptor_position, rooms[idx_best_room], "Distribución mejor cuarto")
plot_room_outline(Lx, Ly, Dx, Dy, source_position, receptor_position, rooms[idx_worst_room], "Distribución peor cuarto")

print("La mejor sala es: ", rooms[idx_best_room])
print("............................")
print("La peor sala es: ", rooms[idx_worst_room])
# Out:
# La mejor sala es:  [[0.625      0.        ]
#  [0.         0.33      ]
#  [0.11       1.54      ]
#  [0.10416667 3.        ]
#  [2.39583333 3.        ]
#  [2.39       1.54      ]
#  [2.5        0.33      ]
#  [1.875      0.        ]]
# ............................
# La peor sala es:  [[0.625      0.        ]
#  [0.         2.09      ]
#  [0.66       2.31      ]
#  [0.10416667 3.        ]
#  [2.39583333 3.        ]
#  [1.84       2.31      ]
#  [2.5        2.09      ]
#  [1.875      0.        ]]

# %% [markdown]
# Resultado con 150 salas

# %%
print(f"El valor de mértio mínimo es: {merit_general[idx_best_room]} | Con SV: {merit_sv_values[idx_best_room]} | Con MD: {merit_md_values[idx_best_room]}" )
print("............................")
print(f"El peor valor de mérito es: {merit_general[idx_worst_room]} | Con SV: {merit_sv_values[idx_worst_room]} | Con MD: {merit_md_values[idx_worst_room]}" )
print("............................")
print("El valor de mértio promedio es: ", np.mean(merit_general))
print("............................")
print("El tiempo de ejecución en minutos fue de: ", (time.time() - start_time)/60)
# Out:
# El valor de mértio mínimo es: 14.23067390546982 | Con SV: 3.416493966917781 | Con MD: 10.814179938552039
# ............................
# El peor valor de mérito es: 21.539823019641688 | Con SV: 5.014071234410941 | Con MD: 16.525751785230746
# ............................
# El valor de mértio promedio es:  17.08800682558826
# ............................
# El tiempo de ejecución en minutos fue de:  38.065536944071454

# %%
plot_room_outline(Lx, Ly, Dx, Dy, source_position, receptor_position, rooms[idx_best_room], "Distribución mejor cuarto")
plot_room_outline(Lx, Ly, Dx, Dy, source_position, receptor_position, rooms[idx_worst_room], "Distribución peor cuarto")

print("La mejor sala es: ", rooms[idx_best_room])
print("............................")
print("La peor sala es: ", rooms[idx_worst_room])
# Out:
# La mejor sala es:  [[0.3125     0.        ]
#  [0.11       0.88      ]
#  [0.22       1.98      ]
#  [0.83333333 3.        ]
#  [1.66666667 3.        ]
#  [2.28       1.98      ]
#  [2.39       0.88      ]
#  [2.1875     0.        ]]
# ............................
# La peor sala es:  [[0.3125     0.        ]
#  [0.         2.2       ]
#  [0.88       2.42      ]
#  [0.83333333 3.        ]
#  [1.66666667 3.        ]
#  [1.62       2.42      ]
#  [2.5        2.2       ]
#  [2.1875     0.        ]]

# %% [markdown]
# Iteración con 250 Salas (1hs)

# %%
print(f"El valor de mértio mínimo es: {merit_general[idx_best_room]} | Con SV: {merit_sv_values[idx_best_room]} | Con MD: {merit_md_values[idx_best_room]}" )
print("............................")
print(f"El peor valor de mérito es: {merit_general[idx_worst_room]} | Con SV: {merit_sv_values[idx_worst_room]} | Con MD: {merit_md_values[idx_worst_room]}" )
print("............................")
print("El valor de mértio promedio es: ", np.mean(merit_general))
print("............................")
print("El tiempo de ejecución en minutos fue de: ", (time.time() - start_time)/60)
# Out:
# El valor de mértio mínimo es: 13.281772637599278 | Con SV: 2.8003109886922024 | Con MD: 10.481461648907075
# ............................
# El peor valor de mérito es: 21.23071423021313 | Con SV: 5.9812377904352285 | Con MD: 15.249476439777903
# ............................
# El valor de mértio promedio es:  16.602724771738174
# ............................
# El tiempo de ejecución en minutos fue de:  73.53687322537104

# %%
plot_room_outline(Lx, Ly, Dx, Dy, source_position, receptor_position, rooms[idx_best_room], "Distribución mejor cuarto")
plot_room_outline(Lx, Ly, Dx, Dy, source_position, receptor_position, rooms[idx_worst_room], "Distribución peor cuarto")

print("La mejor sala es: ", rooms[idx_best_room])
print("............................")
print("La peor sala es: ", rooms[idx_worst_room])
# Out:
# La mejor sala es:  [[0.41666667 0.        ]
#  [0.         0.77      ]
#  [0.11       0.88      ]
#  [0.625      3.        ]
#  [1.875      3.        ]
#  [2.39       0.88      ]
#  [2.5        0.77      ]
#  [2.08333333 0.        ]]
# ............................
# La peor sala es:  [[0.41666667 0.        ]
#  [0.         2.31      ]
#  [1.21       2.64      ]
#  [0.625      3.        ]
#  [1.875      3.        ]
#  [1.29       2.64      ]
#  [2.5        2.31      ]
#  [2.08333333 0.        ]]

# %% [markdown]
# Itreación 300 salas

# %%
print(f"El valor de mértio mínimo es: {merit_general[idx_best_room]} | Con SV: {merit_sv_values[idx_best_room]} | Con MD: {merit_md_values[idx_best_room]}" )
print("............................")
print(f"El peor valor de mérito es: {merit_general[idx_worst_room]} | Con SV: {merit_sv_values[idx_worst_room]} | Con MD: {merit_md_values[idx_worst_room]}" )
print("............................")
print("El valor de mértio promedio es: ", np.mean(merit_general))
print("............................")
print("El tiempo de ejecución en minutos fue de: ", (time.time() - start_time)/60)
# Out:
# El valor de mértio mínimo es: 13.969449029595376 | Con SV: 3.093407525060776 | Con MD: 10.8760415045346
# ............................
# El peor valor de mérito es: 21.25139254447354 | Con SV: 4.512009988042773 | Con MD: 16.739382556430765
# ............................
# El valor de mértio promedio es:  17.01935284940625
# ............................
# El tiempo de ejecución en minutos fue de:  80.50561726888021

# %%
plot_room_outline(Lx, Ly, Dx, Dy, source_position, receptor_position, rooms[idx_best_room], "Distribución mejor cuarto")
plot_room_outline(Lx, Ly, Dx, Dy, source_position, receptor_position, rooms[idx_worst_room], "Distribución peor cuarto")

print("La mejor sala es: ", rooms[idx_best_room])
print("............................")
print("La peor sala es: ", rooms[idx_worst_room])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plot_room_outline(Lx, Ly, Dx, Dy, source_position, receptor_position, rooms[idx_best_room], "Distribución mejor cuarto")
#       2 plot_room_outline(Lx, Ly, Dx, Dy, source_position, receptor_position, rooms[idx_worst_room], "Distribución peor cuarto")
#       4 print("La mejor sala es: ", rooms[idx_best_room])
#
# NameError: name 'plot_room_outline' is not defined
