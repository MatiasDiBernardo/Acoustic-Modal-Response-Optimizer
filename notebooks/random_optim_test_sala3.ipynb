# %% [markdown]
# Optimización aleatoria sala 3

# %%
import os
import time
os.chdir('..')

# %%
from room.geometry_generator import calculation_of_geometry
from mesh.mesh_3D_complex import create_complex_mesh
from FEM.FEM_source import FEM_Source_Solver_Average
from aux.merit_figure import merit_magnitude_deviation, merit_spatial_deviation
from plots.graph_room_outline import plot_room_outline

import numpy as np
import matplotlib.pyplot as plt
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Condiciones de la sala
# Condiciones de la sala
Lx = 4        # Largo de la sala en X 
Ly = 6        # Largo de la sala en Y
Lz = 3        # Alto de la sala
Dx = 0.8      # Delta X
Dy = 1.5      # Delta Y
Dz = 0.5      # Delta Z

## Posiciones fuente y receptor (en metros)
source_position = (3, 4, 1.3)
receptor_position = (2, 2, 1.2)

# %%
# Parametros de control
N = 250        # Densidad de la grilla del generador de geometrías
M = 200        # Cantidad de salas a generar
n_walls = 2    # Número de cortes en las paredes
res_freq = 1

# %%
rooms = calculation_of_geometry(int(Lx * 100), int(Ly * 100), int(Dx * 100), int(Dy * 100), N, M, n_walls)

# %%
# Almacenar toda la data
start_time = time.time()
# rooms = calculation_of_geometry(int(Lx * 100), int(Ly * 100), int(Dx * 100), int(Dy * 100), N, M, n_walls)
mesh = "room_mesh_complex"  # Crear malla con el script correspondiente
mesh1 = "room_mesh_complex1"  # Crear malla con el script correspondiente
mesh2 = "room_mesh_complex2"  # Crear malla con el script correspondiente
mesh3 = "room_mesh_complex3"  # Crear malla con el script correspondiente
mag_responses = []
merit_sv_values = []
merit_md_values = []

# Itera y almacena los valores para encontrar el mejor cuarto
for i in range(M):
    print("Vamos por el room: ", i)

    # Crea la malla de la geometría selecionada
    Z = (Lz - np.random.uniform(0, Dz))
    create_complex_mesh(rooms[i], Z, source_position, 80, mesh1)
    create_complex_mesh(rooms[i], Z, source_position, 140, mesh2)
    create_complex_mesh(rooms[i], Z, source_position, 160, mesh3)

    # Evalua la rta en frecuencia para esa sala
    f1 = np.arange(20, 80, res_freq)
    res1 = FEM_Source_Solver_Average(f1, f'mallado/{mesh1}.msh', receptor_position)

    f2 = np.arange(80, 140, res_freq)
    res2 = FEM_Source_Solver_Average(f2, f'mallado/{mesh2}.msh', receptor_position)

    f3 = np.arange(140, 160, res_freq)
    res3 = FEM_Source_Solver_Average(f3, f'mallado/{mesh3}.msh', receptor_position)

    res_tot = np.hstack([res1, res2, res3])
    res_tot_prom = np.sum(res_tot, axis=0) / 7

    # Calcula figuras de mérito
    sv_merit = merit_spatial_deviation(res_tot)
    md_merit = merit_magnitude_deviation(res_tot)
    
    merit_sv_values.append(sv_merit)
    merit_md_values.append(md_merit)
    mag_responses.append(res_tot_prom)
    print("Vamos por el room: ", i)

f_tot =  np.hstack([f1, f2, f3])
merit_sv_values = np.array(merit_sv_values)
merit_md_values = np.array(merit_md_values)
merit_general = merit_md_values + merit_sv_values

idx_best_room = np.argmin(merit_general)
idx_worst_room = np.argmax(merit_general)

best_room_mag = mag_responses[idx_best_room]
worst_room_mag = mag_responses[idx_worst_room]
random_room_mag = mag_responses[np.random.randint(0, M - 1)]
# Out:
# Vamos por el room:  0
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1060 nodes
# Info    : 5763 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4430 nodes
# Info    : 25761 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6950 nodes
# Info    : 41042 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  0
# Vamos por el room:  1
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1028 nodes
# Info    : 5576 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4056 nodes
# Info    : 23533 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5910 nodes
# Info    : 34657 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  1
# Vamos por el room:  2
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1063 nodes
# Info    : 5811 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4663 nodes
# Info    : 27105 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6618 nodes
# Info    : 39177 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  2
# Vamos por el room:  3
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1303 nodes
# Info    : 7168 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4919 nodes
# Info    : 28667 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7719 nodes
# Info    : 45732 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  3
# Vamos por el room:  4
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1310 nodes
# Info    : 7197 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5109 nodes
# Info    : 29925 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7426 nodes
# Info    : 43943 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  4
# Vamos por el room:  5
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1098 nodes
# Info    : 5969 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4428 nodes
# Info    : 25622 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6746 nodes
# Info    : 39828 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  5
# Vamos por el room:  6
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1258 nodes
# Info    : 6887 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4990 nodes
# Info    : 29301 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7259 nodes
# Info    : 42690 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  6
# Vamos por el room:  7
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1274 nodes
# Info    : 7007 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5187 nodes
# Info    : 30343 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 8010 nodes
# Info    : 47663 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  7
# Vamos por el room:  8
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1343 nodes
# Info    : 7405 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5361 nodes
# Info    : 31490 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 8338 nodes
# Info    : 49571 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  8
# Vamos por el room:  9
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1258 nodes
# Info    : 6911 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5145 nodes
# Info    : 30109 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7710 nodes
# Info    : 45888 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  9
# Vamos por el room:  10
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1377 nodes
# Info    : 7561 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5452 nodes
# Info    : 32016 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 8208 nodes
# Info    : 48782 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  10
# Vamos por el room:  11
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1123 nodes
# Info    : 6126 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 3982 nodes
# Info    : 23045 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6096 nodes
# Info    : 35672 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  11
# Vamos por el room:  12
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1096 nodes
# Info    : 5973 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4206 nodes
# Info    : 24433 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6204 nodes
# Info    : 36176 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  12
# Vamos por el room:  13
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1009 nodes
# Info    : 5487 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 3939 nodes
# Info    : 22626 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5651 nodes
# Info    : 32881 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  13
# Vamos por el room:  14
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1098 nodes
# Info    : 5990 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 3966 nodes
# Info    : 22889 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5881 nodes
# Info    : 34231 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  14
# Vamos por el room:  15
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1141 nodes
# Info    : 6231 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4155 nodes
# Info    : 24111 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6188 nodes
# Info    : 36281 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  15
# Vamos por el room:  16
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1207 nodes
# Info    : 6606 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4612 nodes
# Info    : 26733 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7138 nodes
# Info    : 42069 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  16
# Vamos por el room:  17
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1135 nodes
# Info    : 6164 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4660 nodes
# Info    : 27137 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6933 nodes
# Info    : 40937 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  17
# Vamos por el room:  18
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1157 nodes
# Info    : 6357 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4020 nodes
# Info    : 23220 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5846 nodes
# Info    : 34146 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  18
# Vamos por el room:  19
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1090 nodes
# Info    : 5951 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4573 nodes
# Info    : 26572 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6840 nodes
# Info    : 40410 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  19
# Vamos por el room:  20
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1358 nodes
# Info    : 7519 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5419 nodes
# Info    : 31852 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 8409 nodes
# Info    : 50051 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  20
# Vamos por el room:  21
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1192 nodes
# Info    : 6607 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4538 nodes
# Info    : 26422 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6561 nodes
# Info    : 38552 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  21
# Vamos por el room:  22
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1242 nodes
# Info    : 6815 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5001 nodes
# Info    : 29097 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7545 nodes
# Info    : 44659 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  22
# Vamos por el room:  23
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1132 nodes
# Info    : 6202 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4671 nodes
# Info    : 27195 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6954 nodes
# Info    : 41090 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  23
# Vamos por el room:  24
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1318 nodes
# Info    : 7230 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4943 nodes
# Info    : 28765 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7489 nodes
# Info    : 44303 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  24
# Vamos por el room:  25
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1192 nodes
# Info    : 6604 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5117 nodes
# Info    : 29947 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7680 nodes
# Info    : 45491 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  25
# Vamos por el room:  26
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1167 nodes
# Info    : 6407 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4369 nodes
# Info    : 25258 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6730 nodes
# Info    : 39517 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  26
# Vamos por el room:  27
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1109 nodes
# Info    : 5947 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4481 nodes
# Info    : 25767 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6582 nodes
# Info    : 38318 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  27
# Vamos por el room:  28
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1157 nodes
# Info    : 6323 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4583 nodes
# Info    : 26549 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7043 nodes
# Info    : 41527 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  28
# Vamos por el room:  29
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1379 nodes
# Info    : 7583 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5473 nodes
# Info    : 32394 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 8252 nodes
# Info    : 48938 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  29
# Vamos por el room:  30
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1186 nodes
# Info    : 6540 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4493 nodes
# Info    : 26072 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6477 nodes
# Info    : 37986 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  30
# Vamos por el room:  31
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1289 nodes
# Info    : 7085 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5254 nodes
# Info    : 30707 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 8093 nodes
# Info    : 48054 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  31
# Vamos por el room:  32
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1316 nodes
# Info    : 7308 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5186 nodes
# Info    : 30487 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7947 nodes
# Info    : 47289 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  32
# Vamos por el room:  33
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1121 nodes
# Info    : 6132 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4610 nodes
# Info    : 26768 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6770 nodes
# Info    : 40021 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  33
# Vamos por el room:  34
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1207 nodes
# Info    : 6579 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4672 nodes
# Info    : 27177 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6842 nodes
# Info    : 40415 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  34
# Vamos por el room:  35
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1322 nodes
# Info    : 7320 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5248 nodes
# Info    : 30754 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7518 nodes
# Info    : 44558 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  35
# Vamos por el room:  36
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1055 nodes
# Info    : 5612 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4188 nodes
# Info    : 23851 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6158 nodes
# Info    : 35824 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  36
# Vamos por el room:  37
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1230 nodes
# Info    : 6788 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4094 nodes
# Info    : 23588 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6291 nodes
# Info    : 36769 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  37
# Vamos por el room:  38
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1344 nodes
# Info    : 7423 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5628 nodes
# Info    : 33077 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 8281 nodes
# Info    : 49347 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  38
# Vamos por el room:  39
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1120 nodes
# Info    : 6190 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 3855 nodes
# Info    : 22173 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5670 nodes
# Info    : 33066 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  39
# Vamos por el room:  40
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1285 nodes
# Info    : 7080 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4750 nodes
# Info    : 27658 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6961 nodes
# Info    : 40835 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  40
# Vamos por el room:  41
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1140 nodes
# Info    : 6193 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4754 nodes
# Info    : 27663 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6991 nodes
# Info    : 41358 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  41
# Vamos por el room:  42
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1076 nodes
# Info    : 5914 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4260 nodes
# Info    : 24755 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6305 nodes
# Info    : 36965 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  42
# Vamos por el room:  43
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1245 nodes
# Info    : 6777 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4396 nodes
# Info    : 25628 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6673 nodes
# Info    : 39140 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  43
# Vamos por el room:  44
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1127 nodes
# Info    : 6136 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4539 nodes
# Info    : 26432 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6401 nodes
# Info    : 37685 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  44
# Vamos por el room:  45
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1031 nodes
# Info    : 5590 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4021 nodes
# Info    : 23145 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6097 nodes
# Info    : 35530 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  45
# Vamos por el room:  46
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1179 nodes
# Info    : 6431 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4616 nodes
# Info    : 26900 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7117 nodes
# Info    : 41926 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  46
# Vamos por el room:  47
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1059 nodes
# Info    : 5800 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4102 nodes
# Info    : 23710 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6122 nodes
# Info    : 35843 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  47
# Vamos por el room:  48
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1001 nodes
# Info    : 5446 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 3902 nodes
# Info    : 22528 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5779 nodes
# Info    : 33893 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  48
# Vamos por el room:  49
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1119 nodes
# Info    : 6133 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4412 nodes
# Info    : 25708 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6649 nodes
# Info    : 39408 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  49
# Vamos por el room:  50
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1232 nodes
# Info    : 6713 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4868 nodes
# Info    : 28466 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7397 nodes
# Info    : 43707 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  50
# Vamos por el room:  51
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1081 nodes
# Info    : 5912 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4221 nodes
# Info    : 24405 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6183 nodes
# Info    : 36237 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  51
# Vamos por el room:  52
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1248 nodes
# Info    : 6862 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5252 nodes
# Info    : 30810 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7903 nodes
# Info    : 46844 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  52
# Vamos por el room:  53
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1140 nodes
# Info    : 6320 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4454 nodes
# Info    : 25906 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6588 nodes
# Info    : 38685 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  53
# Vamos por el room:  54
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1191 nodes
# Info    : 6518 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4931 nodes
# Info    : 28755 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7586 nodes
# Info    : 45015 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  54
# Vamos por el room:  55
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1092 nodes
# Info    : 5995 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4169 nodes
# Info    : 24183 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5999 nodes
# Info    : 35145 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  55
# Vamos por el room:  56
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1270 nodes
# Info    : 6955 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4601 nodes
# Info    : 26789 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6894 nodes
# Info    : 40771 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  56
# Vamos por el room:  57
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1279 nodes
# Info    : 6976 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4894 nodes
# Info    : 28401 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7012 nodes
# Info    : 41286 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  57
# Vamos por el room:  58
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1176 nodes
# Info    : 6427 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4657 nodes
# Info    : 27149 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6836 nodes
# Info    : 40494 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  58
# Vamos por el room:  59
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1133 nodes
# Info    : 6138 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4303 nodes
# Info    : 24924 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6581 nodes
# Info    : 38695 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  59
# Vamos por el room:  60
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1185 nodes
# Info    : 6379 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4472 nodes
# Info    : 25652 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6615 nodes
# Info    : 38544 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  60
# Vamos por el room:  61
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1284 nodes
# Info    : 7030 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5001 nodes
# Info    : 29202 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7281 nodes
# Info    : 43228 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  61
# Vamos por el room:  62
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1147 nodes
# Info    : 6326 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4420 nodes
# Info    : 25760 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6454 nodes
# Info    : 37786 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  62
# Vamos por el room:  63
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1071 nodes
# Info    : 5841 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4165 nodes
# Info    : 24068 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6254 nodes
# Info    : 36817 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  63
# Vamos por el room:  64
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1264 nodes
# Info    : 6982 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4464 nodes
# Info    : 25870 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6733 nodes
# Info    : 39501 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  64
# Vamos por el room:  65
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1178 nodes
# Info    : 6466 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4387 nodes
# Info    : 25459 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6499 nodes
# Info    : 38131 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  65
# Vamos por el room:  66
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1018 nodes
# Info    : 5539 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 3714 nodes
# Info    : 21400 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5436 nodes
# Info    : 31657 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  66
# Vamos por el room:  67
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1125 nodes
# Info    : 6100 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4437 nodes
# Info    : 25681 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6387 nodes
# Info    : 37745 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  67
# Vamos por el room:  68
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1262 nodes
# Info    : 6990 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5302 nodes
# Info    : 31117 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 8415 nodes
# Info    : 50000 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  68
# Vamos por el room:  69
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1195 nodes
# Info    : 6506 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4310 nodes
# Info    : 24907 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6472 nodes
# Info    : 38012 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  69
# Vamos por el room:  70
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1329 nodes
# Info    : 7343 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5477 nodes
# Info    : 32143 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 8263 nodes
# Info    : 49205 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  70
# Vamos por el room:  71
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1332 nodes
# Info    : 7360 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4625 nodes
# Info    : 26910 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6922 nodes
# Info    : 40783 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  71
# Vamos por el room:  72
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1094 nodes
# Info    : 5989 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 3790 nodes
# Info    : 21653 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6049 nodes
# Info    : 35264 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  72
# Vamos por el room:  73
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1174 nodes
# Info    : 6420 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4328 nodes
# Info    : 25083 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6479 nodes
# Info    : 37980 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  73
# Vamos por el room:  74
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1077 nodes
# Info    : 5869 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4097 nodes
# Info    : 23731 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5964 nodes
# Info    : 34744 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  74
# Vamos por el room:  75
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1253 nodes
# Info    : 6875 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4508 nodes
# Info    : 26193 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6481 nodes
# Info    : 38208 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  75
# Vamos por el room:  76
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1187 nodes
# Info    : 6460 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4363 nodes
# Info    : 25378 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6591 nodes
# Info    : 38850 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  76
# Vamos por el room:  77
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1424 nodes
# Info    : 7872 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5954 nodes
# Info    : 35016 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 9194 nodes
# Info    : 54996 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  77
# Vamos por el room:  78
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1117 nodes
# Info    : 6075 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4075 nodes
# Info    : 23615 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5987 nodes
# Info    : 34740 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  78
# Vamos por el room:  79
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1347 nodes
# Info    : 7442 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5106 nodes
# Info    : 29931 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7686 nodes
# Info    : 45624 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  79
# Vamos por el room:  80
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1329 nodes
# Info    : 7369 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4701 nodes
# Info    : 27356 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6946 nodes
# Info    : 40864 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  80
# Vamos por el room:  81
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1226 nodes
# Info    : 6691 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4774 nodes
# Info    : 27929 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6970 nodes
# Info    : 41080 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  81
# Vamos por el room:  82
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1447 nodes
# Info    : 7991 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5112 nodes
# Info    : 29910 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7632 nodes
# Info    : 45297 elements
# ...
# Info    : 4182 nodes
# Info    : 24193 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6046 nodes
# Info    : 35553 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  172
# Vamos por el room:  173
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1045 nodes
# Info    : 5718 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4168 nodes
# Info    : 24049 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5924 nodes
# Info    : 34679 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  173
# Vamos por el room:  174
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1168 nodes
# Info    : 6398 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4404 nodes
# Info    : 25711 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6810 nodes
# Info    : 40112 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  174
# Vamos por el room:  175
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1290 nodes
# Info    : 7066 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5140 nodes
# Info    : 29960 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7975 nodes
# Info    : 47072 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  175
# Vamos por el room:  176
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1183 nodes
# Info    : 6499 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 3958 nodes
# Info    : 22777 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6446 nodes
# Info    : 37696 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  176
# Vamos por el room:  177
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1312 nodes
# Info    : 7195 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5056 nodes
# Info    : 29737 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7542 nodes
# Info    : 44700 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  177
# Vamos por el room:  178
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1191 nodes
# Info    : 6507 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4672 nodes
# Info    : 27255 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7050 nodes
# Info    : 41502 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  178
# Vamos por el room:  179
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1309 nodes
# Info    : 7132 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4962 nodes
# Info    : 28998 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7366 nodes
# Info    : 43636 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  179
# Vamos por el room:  180
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1275 nodes
# Info    : 6980 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4813 nodes
# Info    : 28102 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7275 nodes
# Info    : 43018 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  180
# Vamos por el room:  181
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1137 nodes
# Info    : 6150 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 3873 nodes
# Info    : 22117 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6173 nodes
# Info    : 35700 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  181
# Vamos por el room:  182
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1157 nodes
# Info    : 6299 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4166 nodes
# Info    : 24083 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6256 nodes
# Info    : 36760 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  182
# Vamos por el room:  183
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1351 nodes
# Info    : 7375 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4760 nodes
# Info    : 27874 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7171 nodes
# Info    : 42066 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  183
# Vamos por el room:  184
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1466 nodes
# Info    : 8102 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5430 nodes
# Info    : 31882 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7878 nodes
# Info    : 46855 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  184
# Vamos por el room:  185
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1207 nodes
# Info    : 6608 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4425 nodes
# Info    : 25699 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6751 nodes
# Info    : 39623 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  185
# Vamos por el room:  186
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1237 nodes
# Info    : 6796 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4214 nodes
# Info    : 24464 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6281 nodes
# Info    : 36672 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  186
# Vamos por el room:  187
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1472 nodes
# Info    : 8136 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4954 nodes
# Info    : 28885 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7595 nodes
# Info    : 44989 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  187
# Vamos por el room:  188
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1060 nodes
# Info    : 5769 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4152 nodes
# Info    : 24123 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6188 nodes
# Info    : 36337 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  188
# Vamos por el room:  189
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1167 nodes
# Info    : 6435 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4105 nodes
# Info    : 23751 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6093 nodes
# Info    : 35684 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  189
# Vamos por el room:  190
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1117 nodes
# Info    : 6108 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4341 nodes
# Info    : 25133 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6243 nodes
# Info    : 36443 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  190
# Vamos por el room:  191
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1292 nodes
# Info    : 7108 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4745 nodes
# Info    : 27684 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6968 nodes
# Info    : 41280 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  191
# Vamos por el room:  192
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1223 nodes
# Info    : 6750 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 5223 nodes
# Info    : 30660 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 7640 nodes
# Info    : 45460 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  192
# Vamos por el room:  193
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1258 nodes
# Info    : 6919 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4345 nodes
# Info    : 25302 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6499 nodes
# Info    : 38240 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  193
# Vamos por el room:  194
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1191 nodes
# Info    : 6528 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4729 nodes
# Info    : 27387 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6820 nodes
# Info    : 40118 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  194
# Vamos por el room:  195
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1262 nodes
# Info    : 6930 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4916 nodes
# Info    : 28822 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6988 nodes
# Info    : 41351 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  195
# Vamos por el room:  196
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1166 nodes
# Info    : 6371 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4373 nodes
# Info    : 25487 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6608 nodes
# Info    : 38666 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  196
# Vamos por el room:  197
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1220 nodes
# Info    : 6668 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4690 nodes
# Info    : 27299 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6870 nodes
# Info    : 40583 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  197
# Vamos por el room:  198
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1100 nodes
# Info    : 5954 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 3607 nodes
# Info    : 20673 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 5903 nodes
# Info    : 34372 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  198
# Vamos por el room:  199
# Info    : Reading 'mallado/room_mesh_complex1.msh'...
# Info    : 57 entities
# Info    : 1178 nodes
# Info    : 6404 elements
# Info    : Done reading 'mallado/room_mesh_complex1.msh'
# Info    : Reading 'mallado/room_mesh_complex2.msh'...
# Info    : 57 entities
# Info    : 4387 nodes
# Info    : 25517 elements
# Info    : Done reading 'mallado/room_mesh_complex2.msh'
# Info    : Reading 'mallado/room_mesh_complex3.msh'...
# Info    : 57 entities
# Info    : 6807 nodes
# Info    : 40092 elements
# Info    : Done reading 'mallado/room_mesh_complex3.msh'
# Vamos por el room:  199

# %%
print(f"El valor de mértio mínimo es: {merit_general[idx_best_room]} | Con SV: {merit_sv_values[idx_best_room]} | Con MD: {merit_md_values[idx_best_room]}" )
print("............................")
print(f"El peor valor de mérito es: {merit_general[idx_worst_room]} | Con SV: {merit_sv_values[idx_worst_room]} | Con MD: {merit_md_values[idx_worst_room]}" )
print("............................")
print("El valor de mértio promedio es: ", np.mean(merit_general))
print("............................")
print("El tiempo de ejecución en minutos fue de: ", (time.time() - start_time)/60)
# Out:
# El valor de mértio mínimo es: 14.966829913841561 | Con SV: 2.2209842039032686 | Con MD: 12.745845709938292
# ............................
# El peor valor de mérito es: 21.92115173862402 | Con SV: 3.174020646988986 | Con MD: 18.747131091635033
# ............................
# El valor de mértio promedio es:  17.603732660517743
# ............................
# El tiempo de ejecución en minutos fue de:  67.39097152948379

# %%
from complex_outline_optim import calculate_initial

merit_0, mag0 = calculate_initial(Lx, Ly, Lz, source_position, receptor_position)
freq_base = np.arange(20, 160, 1)

# %%
from plots.graph_mag_response import mag_response_comparison

mags = [(freq_base, mag0, "Original"), (freq_base, best_room_mag, "Optimizada")]
mag_response_comparison(mags)

# %%
plot_room_outline(Lx * 100, Ly * 100, Dx * 100, Dy * 100, source_position, receptor_position, rooms[idx_best_room], "Distribución mejor cuarto")
plot_room_outline(Lx * 100, Ly * 100, Dx * 100, Dy * 100, source_position, receptor_position, rooms[idx_worst_room], "Distribución peor cuarto")

print("La mejor sala es: ", rooms[idx_best_room])
print("............................")
print("La peor sala es: ", rooms[idx_worst_room])
